# %% [markdown]
# # 1 - Introduction

# %% [markdown]
# In this lesson we will be discussing the simple interface that [Pandas](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html) provides for interacting with the matplotlib library. In addition, we'll also take a look at the recent changes the matplotlib team has made to make it possible for the two libraries to work together more harmoniously.
#
# Firstly, we will import the same dataset used in the previous Jupyter Notebooks.

# %%
import pandas as pd
import matplotlib.pyplot as plt
reviews = pd.read_csv('fandango_scores.csv')
cols = ['FILM', 'RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue']
norm_reviews = reviews[cols]
norm_reviews.head()
# Out:
#                              FILM  RT_user_norm  Metacritic_user_nom  \
# 0  Avengers: Age of Ultron (2015)           4.3                 3.55
# 1               Cinderella (2015)           4.0                 3.75
# 2                  Ant-Man (2015)           4.5                 4.05
# 3          Do You Believe? (2015)           4.2                 2.35
# 4   Hot Tub Time Machine 2 (2015)           1.4                 1.70
#
#    IMDB_norm  Fandango_Ratingvalue
# 0       3.90                   4.5
# 1       3.55                   4.5
# 2       3.90                   4.5
# 3       2.70                   4.5
# 4       2.55                   3.0

# %% [markdown]
# # 2 -  Histogram

# %% [markdown]
# Just like we did in our EDA example from previous notebooks, we can once again create a simple histogram from our data. This time though, notice that we simply call the **hist** command on the column that contains the education level to plot our data.

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# ['bmh', 'fivethirtyeight', 'seaborn-notebook', '_classic_test', 'ggplot', 'seaborn-white', 'fast', 'seaborn-paper', 'seaborn-talk', 'grayscale', 'seaborn-dark', 'tableau-colorblind10', 'seaborn-muted', 'seaborn-ticks', 'seaborn-whitegrid', 'dark_background', 'seaborn-pastel', 'classic', 'seaborn-colorblind', 'seaborn-bright', 'seaborn-darkgrid', 'seaborn-deep', 'Solarize_Light2', 'seaborn-poster', 'seaborn', 'seaborn-dark-palette']

# %%
plt.style.use('fivethirtyeight')

# %%
# Enable matplotlib plot inline
norm_reviews.Fandango_Ratingvalue.hist(bins=20, range=(0,5))

# %%
# other way to do the same thing
norm_reviews.Fandango_Ratingvalue.plot(kind='hist', bins=20, range=(0,5))

# %%
norm_reviews.plot(kind='hist', bins=20, range=(0,5), alpha=0.3)

# %%
norm_reviews.plot(kind='hist', bins=20, range=(0,5), stacked=True)

# %% [markdown]
# # 3 - Boxplot

# %%
norm_reviews.Fandango_Ratingvalue.plot(kind='box')

# %%
norm_reviews.plot(kind='box',rot=90)

# %% [markdown]
# # 4 - Scatter

# %%
norm_reviews.plot(kind='scatter',x='RT_user_norm', y='Fandango_Ratingvalue')

# %% [markdown]
# # 5 Plotly Express [optional]

# %%
#https://github.com/plotly/plotly_express
# !pip install plotly_express

# %%
import plotly_express as px

# %%
# Cell Configuration for plotly over google colab
# This method pre-populates the outputframe with the configuration that Plotly
# expects and must be executed for every cell which is displaying a Plotly graph.
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-1.5.1.min.js?noext',
            },
          });
        </script>
        '''))

# %%
from plotly.offline import init_notebook_mode

# colab requires to call the fuctions
# below in order to render the figures
configure_plotly_browser_state()
init_notebook_mode(connected=False)

px.histogram(norm_reviews, x="RT_user_norm",
             width=600,histnorm="probability",nbins=20)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from plotly.offline import init_notebook_mode

# colab requires to call the fuctions
# below in order to render the figures
configure_plotly_browser_state()
init_notebook_mode(connected=False)

px.histogram(pd.melt(norm_reviews.drop("FILM",axis=1)),
                     width=900,
                     nbins=20,barmode='relative',
                     color="variable", 
                     x="value")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from plotly.offline import init_notebook_mode
import pandas as pd

# colab requires to call the fuctions
# below in order to render the figures
configure_plotly_browser_state()
init_notebook_mode(connected=False)

px.box(pd.melt(norm_reviews.drop("FILM",axis=1)),
      x="variable", y="value")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from plotly.offline import init_notebook_mode

# colab requires to call the fuctions
# below in order to render the figures
configure_plotly_browser_state()
init_notebook_mode(connected=False)

px.scatter(norm_reviews, x='RT_user_norm', y='Fandango_Ratingvalue')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from plotly.offline import init_notebook_mode

# colab requires to call the fuctions
# below in order to render the figures
configure_plotly_browser_state()
init_notebook_mode(connected=False)

px.scatter(norm_reviews, x='RT_user_norm', y='Fandango_Ratingvalue',
          marginal_y="box",marginal_x="box",trendline="ols")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from plotly.offline import init_notebook_mode

# colab requires to call the fuctions
# below in order to render the figures
configure_plotly_browser_state()
init_notebook_mode(connected=False)

px.scatter_matrix(norm_reviews.drop(labels="FILM",axis=1),
                  height=650)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
